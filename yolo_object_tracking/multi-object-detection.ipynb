# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 16.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
print(YOLO('yolov8n.pt'))
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 86.1MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
# ...

# %%
with open('custom_dataset.yaml', 'w') as f:
    f.write('''train: /kaggle/input/data-for-test/train_data/images/train/
val: /kaggle/input/data-for-test/train_data/images/val/
nc: 13
names: ['auto_rickshaw', 'bicycle', 'bus', 'car', 'cart-vehicle', 'construction_vehicle', 'motorbike', 'person', 'priority_vehicle', 'three-wheeler', 'train', 'truck', 'wheelchair']
''')

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=custom_dataset.yaml epochs=50 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.4 source=/kaggle/input/data1-for-test/dlenigma1/BadODD/images/test/chittagong_bohoddarhat1_1003.jpg
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /kaggle/input/data1-for-test/dlenigma1/BadODD/images/test/chittagong_bohoddarhat1_1003.jpg: 384x640 2 auto_rickshaws, 1 motorbike, 5 persons, 1 three-wheeler, 39.1ms
# Speed: 3.2ms preprocess, 39.1ms inference, 194.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
